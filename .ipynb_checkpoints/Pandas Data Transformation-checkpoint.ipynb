# %% [markdown]
# # Python Transformations with Pandas

# %%
# Download, unzip, and read in the World Bank GDP dataset.

import zipfile36 as zipfile
import wget
import os

print('Beginning file download with wget module')
url = 'http://api.worldbank.org/v2/en/indicator/NY.GDP.MKTP.CD?downloadformat=csv'
wget.download(url, 'gdp data.zip')

with zipfile.ZipFile('gdp data.zip', "r") as z:
    z.extractall("")

# The dataset we need is 'API_NY.GDP.MKTP.CD_DS2_en_csv_v2_713242.csv'
import pandas as pd
gdp = pd.read_csv('API_NY.GDP.MKTP.CD_DS2_en_csv_v2_713242.csv',skiprows=4)
gdp = gdp.drop(['Country Code','Indicator Name','Indicator Code','Unnamed: 64'],axis=1)
gdp.head(2)
# Out:
# Beginning file download with wget module
#   Country Name          1960          1961          1962          1963  \
# 0        Aruba           NaN           NaN           NaN           NaN
# 1  Afghanistan  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
#
#            1964          1965          1966          1967          1968  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09  1.373333e+09  ...
#
#            2010          2011          2012          2013          2014  \
# 0  2.390503e+09  2.549721e+09  2.534637e+09  2.581564e+09  2.649721e+09
# 1  1.585657e+10  1.780428e+10  2.000162e+10  2.056105e+10  2.048487e+10
#
#            2015          2016          2017          2018  2019
# 0  2.691620e+09  2.646927e+09  2.700559e+09           NaN   NaN
# 1  1.990711e+10  1.936264e+10  2.019176e+10  1.936297e+10   NaN
#
# [2 rows x 61 columns]

# %% [markdown]
# ## Transpose

# %%
# Set the Index on Country Name - previously was numeric.
gdp_transpose = gdp.set_index('Country Name')
# Transpose the index and columns
gdp_transpose = gdp_transpose.transpose()
# Reset the index, sets, 'index' as a column
gdp_transpose = gdp_transpose.reset_index()
# Rename the 'index' column to year
gdp_transpose = gdp_transpose.rename(columns={'index':'Year'})
# Set the DataFrame Index to newly named 'Year'
gdp_transpose = gdp_transpose.set_index('Year')
gdp_transpose.head()
# Out:
# Country Name  Aruba   Afghanistan  Angola  Albania  Andorra  Arab World  \
# Year
# 1960            NaN  5.377778e+08     NaN      NaN      NaN         NaN
# 1961            NaN  5.488889e+08     NaN      NaN      NaN         NaN
# 1962            NaN  5.466667e+08     NaN      NaN      NaN         NaN
# 1963            NaN  7.511112e+08     NaN      NaN      NaN         NaN
# 1964            NaN  8.000000e+08     NaN      NaN      NaN         NaN
#
# Country Name  United Arab Emirates     Argentina  Armenia  American Samoa  \
# Year
# 1960                           NaN           NaN      NaN             NaN
# 1961                           NaN           NaN      NaN             NaN
# 1962                           NaN  2.445060e+10      NaN             NaN
# 1963                           NaN  1.827212e+10      NaN             NaN
# 1964                           NaN  2.560525e+10      NaN             NaN
#
# Country Name  ...  Virgin Islands (U.S.)  Vietnam  Vanuatu         World  \
# Year          ...
# 1960          ...                    NaN      NaN      NaN  1.372745e+12
# 1961          ...                    NaN      NaN      NaN  1.428067e+12
# 1962          ...                    NaN      NaN      NaN  1.532502e+12
# 1963          ...                    NaN      NaN      NaN  1.650922e+12
# 1964          ...                    NaN      NaN      NaN  1.808554e+12
#
# Country Name  Samoa  Kosovo  Yemen, Rep.  South Africa        Zambia  \
# Year
# 1960            NaN     NaN          NaN  7.575397e+09  7.130000e+08
# 1961            NaN     NaN          NaN  7.972997e+09  6.962857e+08
# 1962            NaN     NaN          NaN  8.497997e+09  6.931429e+08
# 1963            NaN     NaN          NaN  9.423396e+09  7.187143e+08
# 1964            NaN     NaN          NaN  1.037400e+10  8.394286e+08
#
# Country Name      Zimbabwe
# Year
# 1960          1.052990e+09
# 1961          1.096647e+09
# 1962          1.117602e+09
# 1963          1.159512e+09
# 1964          1.217138e+09
#
# [5 rows x 264 columns]

# %% [markdown]
# ## Percent Change

# %%
gdp_pct_diff = gdp_transpose
gdp_pct_diff = gdp_pct_diff.pct_change()
gdp_pct_diff.head()
# Out:
# Country Name  Aruba  Afghanistan  Angola  Albania  Andorra  Arab World  \
# Year
# 1960            NaN          NaN     NaN      NaN      NaN         NaN
# 1961            NaN     0.020661     NaN      NaN      NaN         NaN
# 1962            NaN    -0.004049     NaN      NaN      NaN         NaN
# 1963            NaN     0.373984     NaN      NaN      NaN         NaN
# 1964            NaN     0.065089     NaN      NaN      NaN         NaN
#
# Country Name  United Arab Emirates  Argentina  Armenia  American Samoa  ...  \
# Year                                                                    ...
# 1960                           NaN        NaN      NaN             NaN  ...
# 1961                           NaN        NaN      NaN             NaN  ...
# 1962                           NaN        NaN      NaN             NaN  ...
# 1963                           NaN  -0.252692      NaN             NaN  ...
# 1964                           NaN   0.401329      NaN             NaN  ...
#
# Country Name  Virgin Islands (U.S.)  Vietnam  Vanuatu     World  Samoa  \
# Year
# 1960                            NaN      NaN      NaN       NaN    NaN
# 1961                            NaN      NaN      NaN  0.040300    NaN
# 1962                            NaN      NaN      NaN  0.073131    NaN
# 1963                            NaN      NaN      NaN  0.077272    NaN
# 1964                            NaN      NaN      NaN  0.095481    NaN
#
# Country Name  Kosovo  Yemen, Rep.  South Africa    Zambia  Zimbabwe
# Year
# 1960             NaN          NaN           NaN       NaN       NaN
# 1961             NaN          NaN      0.052486 -0.023442  0.041459
# 1962             NaN          NaN      0.065847 -0.004514  0.019108
# 1963             NaN          NaN      0.108896  0.036892  0.037500
# 1964             NaN          NaN      0.100877  0.167959  0.049699
#
# [5 rows x 264 columns]

# %% [markdown]
# ## Transpose Back

# %%
gdp_pct_diff_transpose = gdp_pct_diff.transpose().reset_index()
gdp_pct_diff_transpose.head()
# Out:
# Year Country Name  1960      1961      1962      1963      1964      1965  \
# 0           Aruba   NaN       NaN       NaN       NaN       NaN       NaN
# 1     Afghanistan   NaN  0.020661 -0.004049  0.373984  0.065089  0.258333
# 2          Angola   NaN       NaN       NaN       NaN       NaN       NaN
# 3         Albania   NaN       NaN       NaN       NaN       NaN       NaN
# 4         Andorra   NaN       NaN       NaN       NaN       NaN       NaN
#
# Year      1966      1967      1968  ...      2010      2011      2012  \
# 0          NaN       NaN       NaN  ... -0.043371  0.066604 -0.005916
# 1     0.390728  0.195238 -0.179283  ...  0.274738  0.122833  0.123416
# 2          NaN       NaN       NaN  ...  0.191906  0.334014  0.145480
# 3          NaN       NaN       NaN  ... -0.009736  0.080817 -0.044301
# 4          NaN       NaN       NaN  ... -0.083276  0.025738 -0.080605
#
# Year      2013      2014      2015      2016      2017      2018  2019
# 0     0.018514  0.026401  0.015813 -0.016604  0.020262  0.000000   0.0
# 1     0.027970 -0.003705 -0.028204 -0.027350  0.042821 -0.041046   0.0
# 2     0.067605  0.065850 -0.202581 -0.129696  0.207666 -0.134067   0.0
# 3     0.037054  0.035375 -0.139196  0.041664  0.098109  0.159495   0.0
# 4     0.036962  0.021072 -0.160934  0.023412  0.047293  0.074055   0.0
#
# [5 rows x 61 columns]

# %% [markdown]
# ## Melt
# - Melt both dataframes and merge them

# %%
# Pure GDP DataFrame

melted_gdp = pd.melt(gdp,id_vars=['Country Name'],
                    value_vars=gdp.columns[1:],
                    var_name='Year',
                    value_name='GDP')
melted_gdp.head()
# Out:
#   Country Name  Year           GDP
# 0        Aruba  1960           NaN
# 1  Afghanistan  1960  5.377778e+08
# 2       Angola  1960           NaN
# 3      Albania  1960           NaN
# 4      Andorra  1960           NaN

# %%
# GDP Percent Difference DataFrame

melted_gdp_pct_diff = pd.melt(gdp_pct_diff_transpose,id_vars=['Country Name'],
                              value_vars=gdp_pct_diff_transpose.columns[1:],
                              var_name='Year',
                              value_name='GDP')
melted_gdp_pct_diff.tail()
# Out:
#        Country Name  Year  GDP
# 15835        Kosovo  2019  0.0
# 15836   Yemen, Rep.  2019  0.0
# 15837  South Africa  2019  0.0
# 15838        Zambia  2019  0.0
# 15839      Zimbabwe  2019  0.0

# %% [markdown]
# ## Merge

# %%
df = melted_gdp.merge(melted_gdp_pct_diff, left_index=True, right_index=True)
df.head()
# Out:
#   Country Name_x Year_x         GDP_x Country Name_y Year_y  GDP_y
# 0          Aruba   1960           NaN          Aruba   1960    NaN
# 1    Afghanistan   1960  5.377778e+08    Afghanistan   1960    NaN
# 2         Angola   1960           NaN         Angola   1960    NaN
# 3        Albania   1960           NaN        Albania   1960    NaN
# 4        Andorra   1960           NaN        Andorra   1960    NaN

# %% [markdown]
# ## Drop columns, Rename, Cast to Numeric, Drop NAs

# %%
# Drop 2 columns
df = df.drop(['Country Name_y','Year_y',], axis=1)
# Rename 4 columns
df = df.rename(columns={'Country Name_x':'Country Name',
                        'Year_x':'Year',
                        'GDP_x':'GDP',
                        'GDP_y':'GDP_pct_change'})
# Cast Year to a numeric dtype
df['Year'] = pd.to_numeric(df['Year'])
# Drop NAs
df = df.dropna()

df.head()
# Out:
#     Country Name  Year           GDP  GDP_pct_change
# 265  Afghanistan  1961  5.488889e+08        0.020661
# 275    Australia  1961  1.965282e+10        0.057873
# 276      Austria  1961  7.311750e+09        0.109069
# 278      Burundi  1961  2.030000e+08        0.035714
# 279      Belgium  1961  1.240015e+10        0.063594

# %% [markdown]
# ## GDP Per Year per Quartile
# Excellent stackoverflow answer: https://stackoverflow.com/questions/19403133/pandas-groupby-and-qcut

# %%
gdp_quartile = df
gdp_quartile['Quartile'] = gdp_quartile.groupby(['Year'])['GDP'].transform(
                     lambda x: pd.qcut(x, 4, labels=range(1,5)))
gdp_quartile.head()
# Out:
#     Country Name  Year           GDP  GDP_pct_change  Quartile
# 265  Afghanistan  1961  5.488889e+08        0.020661       2.0
# 275    Australia  1961  1.965282e+10        0.057873       3.0
# 276      Austria  1961  7.311750e+09        0.109069       3.0
# 278      Burundi  1961  2.030000e+08        0.035714       1.0
# 279      Belgium  1961  1.240015e+10        0.063594       3.0

# %% [markdown]
# ## Average GDP pct change by Quartile per year

# %%
pct_change = gdp_quartile
# Group by Year and Quartile, focus the mean calculation on GDP_pct_change
pct_change = pd.DataFrame(pct_change.groupby(['Year','Quartile'])['GDP_pct_change'].mean())
# Rename the calculated column to Average GDP Pct Change
pct_change = pct_change.rename(columns={'GDP_pct_change':'Average GDP Pct Change'}).reset_index()

pct_change.head()
# Out:
#    Year  Quartile  Average GDP Pct Change
# 0  1961       1.0                0.069361
# 1  1961       2.0                0.029803
# 2  1961       3.0                0.065812
# 3  1961       4.0                0.021617
# 4  1962       1.0                0.061953

# %% [markdown]
# ## Line Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection

# Initialize figure and size of the plot
plt.figure(figsize=(14,8))

# Seaborn line plot
ax = sns.lineplot(x='Year',y='Average GDP Pct Change',
                  data=pct_change,
                  hue='Quartile',
                  palette='Accent')

# Create a dashed line at zero for comparison
ax.annotate("",
            xy=(1961, 0), xycoords='data',
            xytext=(2019, 0), textcoords='data',
            arrowprops=dict(arrowstyle="-",
                            ls='dashed',
                            edgecolor = "red",
                            connectionstyle="arc3, rad=0"),
           )


# Set xtick labels and rotate the x-axis labels
plt.setp(ax.get_xticklabels(), rotation=90)
# Set the title
plt.title('Average GDP Percent Change per Year - Quartiles')

plt.tight_layout()
# Grab the figure
fig = ax.get_figure()
# Save the figure
fig.savefig('Avg GDP pct change')
